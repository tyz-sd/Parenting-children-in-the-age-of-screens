# %%
'''
Part of what I want to study is whether or not the place of residence affects a child's ability to hold their own social accounts. We found that Suburban > Urban > Rural
'''

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Create the picture 
plt.figure(figsize=(10, 6))  
sns.histplot(data, x='Social_media_user', hue='P_neighborhood', multiple='stack')
plt.title('Distribution of Social Media User by Neighborhood')
plt.xlabel('Social Media User')
plt.ylabel('Frequency')
plt.xticks(rotation=0, fontsize=12)  # Rotate the degree and change the word size
plt.yticks(fontsize=12)
plt.tight_layout()  
plt.show()

# %%
'''
For the next part, we need to consider whether living in a SUBURBAN is more indulgent in cell phone play with their kids (e.g. they are more likely to allow their kids to use their cell phones in the car than parents elsewhere)
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Ensure 'ALLOW_in_car' is a categorical variable with the desired order
category_order = ["Yes, I would allow this", "No, I would not allow this", "Refused"]
data['ALLOW_in_car'] = pd.Categorical(data['ALLOW_in_car'], categories=category_order, ordered=True)

# Create the picture 
plt.figure(figsize=(10, 6))  
sns.histplot(data, x='ALLOW_in_car', hue='P_neighborhood', multiple='stack')
plt.title('Distribution of allowing children to play with cell phones in the car by Neighborhood')
plt.xlabel('Whether children are allowed to play with cell phones in the car')
plt.ylabel('Frequency')
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout() 
plt.show()

# %%
'''
Let's check other time periods (like home_dinner time)
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Ensure 'ALLOW_in_car' is a categorical variable with the desired order
category_order = ["Yes, I would allow this", "No, I would not allow this", "Refused"]
data['ALLOW_home_dinner'] = pd.Categorical(data['ALLOW_home_dinner'], categories=category_order, ordered=True)

# Create the picture 
plt.figure(figsize=(10, 6))  
sns.histplot(data, x='ALLOW_home_dinner', hue='P_neighborhood', multiple='stack')
plt.title('Distribution of allowing children to play with cell phones in the home dinner time by Neighborhood')
plt.xlabel('Whether children are allowed to play with cell phones in the home dinner time')
plt.ylabel('Frequency')
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout() 
plt.show()

# %%
'''
outside_dinner time
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Ensure 'ALLOW_in_car' is a categorical variable with the desired order
category_order = ["Yes, I would allow this", "No, I would not allow this", "Refused"]
data['ALLOW_outside_dinner'] = pd.Categorical(data['ALLOW_outside_dinner'], categories=category_order, ordered=True)

# Create the picture 
plt.figure(figsize=(10, 6))  
sns.histplot(data, x='ALLOW_outside_dinner', hue='P_neighborhood', multiple='stack')
plt.title('Distribution of allowing children to play with cell phones in the outside dinner time by Neighborhood')
plt.xlabel('Whether children are allowed to play with cell phones in the outside dinner time')
plt.ylabel('Frequency')
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout() 
plt.show()

# %%
'''
before bed
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Ensure 'ALLOW_in_car' is a categorical variable with the desired order
category_order = ["Yes, I would allow this", "No, I would not allow this", "Refused"]
data['ALLOW_before_bed'] = pd.Categorical(data['ALLOW_before_bed'], categories=category_order, ordered=True)

# Create the picture 
plt.figure(figsize=(10, 6))  
sns.histplot(data, x='ALLOW_before_bed', hue='P_neighborhood', multiple='stack')
plt.title('Distribution of allowing children to play with cell phones before bed by Neighborhood')
plt.xlabel('Whether children are allowed to play with cell phones before bed')
plt.ylabel('Frequency')
plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout() 
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Calculate the frequency of each type of social media usage time per region
freq_data = data.groupby(['P_neighborhood', 'TS_on_socialmedia']).size().reset_index(name='Frequency')

# Set style
sns.set_style("whitegrid")

# Create a color palette
palette = sns.color_palette("muted")

# Create graph
plt.figure(figsize=(10, 6))
sns.barplot(x='P_neighborhood', y='Frequency', hue='TS_on_socialmedia', data=freq_data, palette=palette)

# Enhance plot aesthetics
plt.title('Distribution of Time Spent on Social Media by Region', fontsize=14)
plt.xlabel('Area', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), title="Time Spent on Social Media")

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Calculate the frequency of each type of social media usage time per region
freq_data = data.groupby(['P_neighborhood', 'TS_on_socialmedia']).size().reset_index(name='Frequency')

# Set style
sns.set_style("whitegrid")

# Create a color palette
palette = sns.color_palette("muted")

# Create graph with a smaller size
plt.figure(figsize=(8, 4))  # Adjusted to a smaller size
sns.barplot(x='P_neighborhood', y='Frequency', hue='TS_on_socialmedia', data=freq_data, palette=palette)

# Enhance plot aesthetics
plt.title('Distribution of Time Spent on Social Media by Region', fontsize=12)
plt.xlabel('Area', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), title="Time Spent on Social Media")

# Show the plot
plt.show()

# %%
'''
How old is the average child?
'''
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('pre_processed_data.csv')

# Group children by neighborhood and calculate the total number of children in each age group
grouped_data = data.groupby('P_neighborhood')[['No_of_kids_0_4', 'No_of_kids_5_11', 'No_of_kids_12_17', 'No_of_kids_above_18']].sum()

grouped_data.plot(kind='bar', stacked=True, figsize=(10, 7))

# Add title and label 
plt.title('Number of Children by Age Group and Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Children')
plt.xticks(rotation=0)  

# Add the title
plt.legend(title='Age groups', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the list
plt.tight_layout()  
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Number of children at home
grouped_data = data.groupby('P_neighborhood')[['No_of_kids_at_home_0_11', 'No_of_kids_at_home_above_12']].sum()

# Set style
sns.set_style("whitegrid")

# Create a color palette
palette = sns.color_palette("Set2")

# Create and enhance the plot
plt.figure(figsize=(10, 7))
grouped_data.plot(kind='bar', stacked=True, color=palette, width=0.8, edgecolor='black')

# Add titles and labels with enhanced font sizes
plt.title('Number of Children at Home by Age Group and Location', fontsize=14)
plt.xlabel('Location', fontsize=12)
plt.ylabel('Number of Children at Home', fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.yticks(fontsize=10)

# Enhance the legend
plt.legend(title='Age Groups at Home', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)

# Adjust layout and add gridlines
plt.tight_layout()
plt.grid(True)

# Show the plot
plt.show()

# %%
pip install -U seaborn
# Out:
# ...
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/7b/e5/83fcd7e9db036c179e0352bfcd20f81d728197a16f883e7b90307a88e65e/seaborn-0.13.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 900.4 kB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
'''
Age of owning the phone 
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Create the picture 
plt.figure(figsize=(10, 6))  
sns.histplot(data, x='Child_owns_smartphone_age', hue='P_neighborhood', multiple='stack')
plt.title('Distribution of Age own a phone by living area')
plt.xlabel('Age own a phone')
plt.ylabel('Frequency')
plt.xticks(rotation=0, fontsize=12)  # Rotate the degree and change the word size
plt.yticks(fontsize=12)
plt.tight_layout()  
plt.show()

# %%
'''
Parent job type
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Create the picture 
plt.figure(figsize=(10, 6))  
sns.histplot(data, x='P_employment_type', hue='P_neighborhood', multiple='stack')
plt.title('Distribution of Age own a phone by living area')
plt.xlabel('Parent job type')
plt.ylabel('Frequency')
plt.xticks(rotation=0, fontsize=12)  # Rotate the degree and change the word size
plt.yticks(fontsize=12)
plt.tight_layout()  
plt.show()

# %%
'''
Parent region
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Create the picture 
plt.figure(figsize=(10, 6))  
sns.histplot(data, x='P_region', hue='P_neighborhood', multiple='stack')
plt.title('Distribution of parent region by living area')
plt.xlabel('Parent region')
plt.ylabel('Frequency')
plt.xticks(rotation=0, fontsize=12)  # Rotate the degree and change the word size
plt.yticks(fontsize=12)
plt.tight_layout()  
plt.show()
'''The South is economically depressed(or not good from history) relative to the rest of the country'''
# Out:
# 'The South is economically depressed(or not good from history) relative to the rest of the country'

# %%
'''The reason why parent allow their children have phone'''
# Out:
# 'The reason why parent allow their children have phone'

# %%
'''
But why do these parents think what they think? The latter also needs to be analyzed is ins, facebook, what software they think their children are overly addicted to [1. facebook]
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Ensure 'ALLOW_in_car' is a categorical variable with the desired order
category_order = ["Yes, my child uses this", "No, my child does not use this"]
data['CHSO_facebook'] = pd.Categorical(data['CHSO_facebook'], categories=category_order, ordered=True)

# Create the picture 
plt.figure(figsize=(10, 6))  
sns.histplot(data, x='CHSO_facebook', hue='P_neighborhood', multiple='stack')
plt.title('Distribution of Facebook User by Neighborhood')
plt.xlabel('Facebook User')
plt.ylabel('Frequency')
plt.xticks(rotation=0, fontsize=12)  # Rotate the degree and change the word size
plt.yticks(fontsize=12)
plt.tight_layout()  
plt.show()

# %%
'''
But why do these parents think what they think? What needs to be analyzed later is ins, facebook, what software they think their kids are overly addicted to [2. instagram]
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Ensure 'ALLOW_in_car' is a categorical variable with the desired order
category_order = ["Yes, my child uses this", "No, my child does not use this"]
data['CHSO_instagram'] = pd.Categorical(data['CHSO_instagram'], categories=category_order, ordered=True)

# Create the picture 
plt.figure(figsize=(10, 6))  
sns.histplot(data, x='CHSO_instagram', hue='P_neighborhood', multiple='stack')
plt.title('Distribution of Instagram User by Neighborhood')
plt.xlabel('Instagram User')
plt.ylabel('Frequency')
plt.xticks(rotation=0, fontsize=12)  # Rotate the degree and change the word size
plt.yticks(fontsize=12)
plt.tight_layout()  
plt.show()

# %%
'''
But why do these parents think that? The latter also needs to be analyzed is ins, facebook, what software they think their kids are overly addicted to [3. snapchat]
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Ensure 'ALLOW_in_car' is a categorical variable with the desired order
category_order = ["Yes, my child uses this", "No, my child does not use this", "Refused"]
data['CHSO_snapchat'] = pd.Categorical(data['CHSO_snapchat'], categories=category_order, ordered=True)

# Create the picture 
plt.figure(figsize=(10, 6))  
sns.histplot(data, x='CHSO_snapchat', hue='P_neighborhood', multiple='stack')
plt.title('Distribution of snapchat User by Neighborhood')
plt.xlabel('snapchat User')
plt.ylabel('Frequency')
plt.xticks(rotation=0, fontsize=12)  # Rotate the degree and change the word size
plt.yticks(fontsize=12)
plt.tight_layout()  
plt.show()

# %%
'''
But why do these parents think what they think? The latter also needs to be analyzed is ins, facebook, what software they think their kids are overly addicted to [3. tiktok]
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Ensure 'ALLOW_in_car' is a categorical variable with the desired order
category_order = ["Yes, my child uses this", "No, my child does not use this", "Refused"]
data['CHSO_tiktok'] = pd.Categorical(data['CHSO_tiktok'], categories=category_order, ordered=True)

# Create the picture 
plt.figure(figsize=(10, 6))  
sns.histplot(data, x='CHSO_tiktok', hue='P_neighborhood', multiple='stack')
plt.title('Distribution of tiktok User by Neighborhood')
plt.xlabel('tiktok User')
plt.ylabel('Frequency')
plt.xticks(rotation=0, fontsize=12)  # Rotate the degree and change the word size
plt.yticks(fontsize=12)
plt.tight_layout()  
plt.show()

# %%
'''
But why do these parents think that? What needs to be analyzed later is ins, facebook, what software they think their children are overly addicted to [3. other_websites]
'''
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Ensure 'ALLOW_in_car' is a categorical variable with the desired order
category_order = ["Yes, my child uses this", "No, my child does not use this", "Refused"]
data['CHSO_other_websites'] = pd.Categorical(data['CHSO_other_websites'], categories=category_order, ordered=True)

# Create the picture 
plt.figure(figsize=(10, 6))  
sns.histplot(data, x='CHSO_other_websites', hue='P_neighborhood', multiple='stack')
plt.title('Distribution of other websites User by Neighborhood')
plt.xlabel('other websites User')
plt.ylabel('Frequency')
plt.xticks(rotation=0, fontsize=12)  # Rotate the degree and change the word size
plt.yticks(fontsize=12)
plt.tight_layout()  
plt.show()

# %%
'''
Check video game
'''
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Calculate the frequency of each type of social media usage time per region
freq_data = data.groupby(['P_neighborhood', 'HCHU_videogames']).size().reset_index(name='Frequency')

# Create graph
plt.figure(figsize=(10, 6))
sns.barplot(x='P_neighborhood', y='Frequency', hue='HCHU_videogames', data=freq_data)
plt.title('Distribution of time spent on video game by region')
plt.xlabel('Area')
plt.ylabel('Frequency')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('pre_processed_data.csv')  

# Counting the number of "Yes" and "No's"
yes_count = df['CHD_tv'].value_counts()['Yes, my child uses or interacts with this']
no_count = df['CHD_tv'].value_counts()['No, my child does not use or interact with this']

# Calculate the total number
total_count = len(df['CHD_tv'])

# Calculate the percentage 
yes_percentage = (yes_count / total_count) * 100
no_percentage = (no_count / total_count) * 100

plt.figure(figsize=(10, 6))


# Create bar charts
plt.bar('Yes, my child uses or interacts with this', yes_count, color='blue')
plt.bar('No, my child does not use or interact with this', no_count, color='orange')

# Add text labeling percentages to bar charts

plt.text('Yes, my child uses or interacts with this', yes_count, f'{yes_percentage:.2f}%', ha='center', va='bottom')
plt.text('No, my child does not use or interact with this', no_count, f'{no_percentage:.2f}%', ha='center', va='bottom')

# Set the label and title
plt.title('Number and percentage of "Yes" and "No" responses')
plt.xlabel('TV interacts')
plt.ylabel('quantities')

# Adjust the angle of the x-axis labels to avoid overlapping
plt.xticks(rotation=0, ha='right')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('pre_processed_data.csv')  

# Counting the number of "Yes" and "No's"
yes_count = df['CHD_computer'].value_counts()['Yes, my child uses or interacts with this']
no_count = df['CHD_computer'].value_counts()['No, my child does not use or interact with this']

# Calculate the total number
total_count = len(df['CHD_computer'])

# Calculate the percentage 
yes_percentage = (yes_count / total_count) * 100
no_percentage = (no_count / total_count) * 100

plt.figure(figsize=(10, 6))


# Create bar charts
plt.bar('Yes, my child uses or interacts with this', yes_count, color='blue')
plt.bar('No, my child does not use or interact with this', no_count, color='orange')

# Add text labeling percentages to bar charts

plt.text('Yes, my child uses or interacts with this', yes_count, f'{yes_percentage:.2f}%', ha='center', va='bottom')
plt.text('No, my child does not use or interact with this', no_count, f'{no_percentage:.2f}%', ha='center', va='bottom')

# Set the label and title
plt.title('Number and percentage of "Yes" and "No" responses')
plt.xlabel('computer interacts')
plt.ylabel('quantities')

# Adjust the angle of the x-axis labels to avoid overlapping
plt.xticks(rotation=0, ha='right')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('pre_processed_data.csv')  

# Counting the number of "Yes" and "No's"
yes_count = df['CHD_tablet'].value_counts()['Yes, my child uses or interacts with this']
no_count = df['CHD_tablet'].value_counts()['No, my child does not use or interact with this']

# Calculate the total number
total_count = len(df['CHD_tablet'])

# Calculate the percentage 
yes_percentage = (yes_count / total_count) * 100
no_percentage = (no_count / total_count) * 100

plt.figure(figsize=(10, 6))


# Create bar charts
plt.bar('Yes, my child uses or interacts with this', yes_count, color='blue')
plt.bar('No, my child does not use or interact with this', no_count, color='orange')

# Add text labeling percentages to bar charts

plt.text('Yes, my child uses or interacts with this', yes_count, f'{yes_percentage:.2f}%', ha='center', va='bottom')
plt.text('No, my child does not use or interact with this', no_count, f'{no_percentage:.2f}%', ha='center', va='bottom')

# Set the label and title
plt.title('Number and percentage of "Yes" and "No" responses')
plt.xlabel('tablet interacts')
plt.ylabel('quantities')

# Adjust the angle of the x-axis labels to avoid overlapping
plt.xticks(rotation=0, ha='right')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('pre_processed_data.csv')  

# Counting the number of "Yes" and "No's"
yes_count = df['CHD_gaming_console'].value_counts()['Yes, my child uses or interacts with this']
no_count = df['CHD_gaming_console'].value_counts()['No, my child does not use or interact with this']

# Calculate the total number
total_count = len(df['CHD_gaming_console'])

# Calculate the percentage 
yes_percentage = (yes_count / total_count) * 100
no_percentage = (no_count / total_count) * 100

plt.figure(figsize=(10, 6))


# Create bar charts
plt.bar('Yes, my child uses or interacts with this', yes_count, color='blue')
plt.bar('No, my child does not use or interact with this', no_count, color='orange')

# Add text labeling percentages to bar charts

plt.text('Yes, my child uses or interacts with this', yes_count, f'{yes_percentage:.2f}%', ha='center', va='bottom')
plt.text('No, my child does not use or interact with this', no_count, f'{no_percentage:.2f}%', ha='center', va='bottom')

# Set the label and title
plt.title('Number and percentage of "Yes" and "No" responses')
plt.xlabel('gaming_console interacts')
plt.ylabel('quantities')

# Adjust the angle of the x-axis labels to avoid overlapping
plt.xticks(rotation=0, ha='right')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('pre_processed_data.csv')  

# Counting the number of "Yes" and "No's"
yes_count = df['CHD_voice_assistant'].value_counts()['Yes, my child uses or interacts with this']
no_count = df['CHD_voice_assistant'].value_counts()['No, my child does not use or interact with this']

# Calculate the total number
total_count = len(df['CHD_voice_assistant'])

# Calculate the percentage 
yes_percentage = (yes_count / total_count) * 100
no_percentage = (no_count / total_count) * 100

plt.figure(figsize=(10, 6))


# Create bar charts
plt.bar('Yes, my child uses or interacts with this', yes_count, color='blue')
plt.bar('No, my child does not use or interact with this', no_count, color='orange')

# Add text labeling percentages to bar charts

plt.text('Yes, my child uses or interacts with this', yes_count, f'{yes_percentage:.2f}%', ha='center', va='bottom')
plt.text('No, my child does not use or interact with this', no_count, f'{no_percentage:.2f}%', ha='center', va='bottom')

# Set the label and title
plt.title('Number and percentage of "Yes" and "No" responses')
plt.xlabel('voice_assistant interacts')
plt.ylabel('quantities')

# Adjust the angle of the x-axis labels to avoid overlapping
plt.xticks(rotation=0, ha='right')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('pre_processed_data.csv')  

# Counting the number of "Yes" and "No's"
yes_count = df['CHD_smartphone'].value_counts()['Yes, my child uses or interacts with this']
no_count = df['CHD_smartphone'].value_counts()['No, my child does not use or interact with this']

# Calculate the total number
total_count = len(df['CHD_smartphone'])

# Calculate the percentage 
yes_percentage = (yes_count / total_count) * 100
no_percentage = (no_count / total_count) * 100

plt.figure(figsize=(10, 6))


# Create bar charts
plt.bar('Yes, my child uses or interacts with this', yes_count, color='blue')
plt.bar('No, my child does not use or interact with this', no_count, color='orange')

# Add text labeling percentages to bar charts

plt.text('Yes, my child uses or interacts with this', yes_count, f'{yes_percentage:.2f}%', ha='center', va='bottom')
plt.text('No, my child does not use or interact with this', no_count, f'{no_percentage:.2f}%', ha='center', va='bottom')

# Set the label and title
plt.title('Number and percentage of "Yes" and "No" responses')
plt.xlabel('smartphone interacts')
plt.ylabel('quantities')

# Adjust the angle of the x-axis labels to avoid overlapping
plt.xticks(rotation=0, ha='right')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
file_path = 'pre_processed_data.csv'  
data = pd.read_csv(file_path)

# Selecting and renaming the required columns
columns_of_interest = ['CHD_smartphone', 'CHD_voice_assistant', 'CHD_gaming_console', 'CHD_tablet', 'CHD_computer', 'CHD_tv']
display_column_names = {'CHD_smartphone': 'Smartphone', 'CHD_voice_assistant': 'Voice Assistant', 'CHD_gaming_console': 'Gaming Console', 'CHD_tablet': 'Tablet', 'CHD_computer': 'Computer', 'CHD_tv': 'TV'}
data_selected = data[columns_of_interest].rename(columns=display_column_names)

# Calculating the percentage of 'Yes' and 'No' for each column
percentages = {}
for col in display_column_names.values():
    counts = data_selected[col].value_counts(normalize=True)
    percentages[col] = {
        'Yes': counts.get('Yes, my child uses or interacts with this', 0) * 100,
        'No': counts.get('No, my child does not use or interact with this', 0) * 100
    }

# Creating a DataFrame for easy plotting
percentages_df = pd.DataFrame(percentages).T

# Plotting with percentage annotations
fig, ax = plt.subplots(figsize=(8, 4))  # Adjusted to a smaller size
percentages_df.plot(kind='bar', stacked=True, ax=ax)

# Adding the percentage annotations
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height:.1f}%', (x + width/2, y + height/2), ha='center')

# Setting the plot details
plt.title('Percentage of Responses for Different Technologies Usage', fontsize=12)
plt.xlabel('Technologies', fontsize=10)
plt.ylabel('Percentage (%)', fontsize=10)
plt.xticks(rotation=45, fontsize=8)
plt.yticks(fontsize=8)
plt.legend(title='Response', fontsize=8)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Calculate the frequency of each type of social media usage time per region
freq_data = data.groupby(['P_neighborhood', 'TS_on_socialmedia']).size().reset_index(name='Frequency')

# Create graph for social media usage
plt.figure(figsize=(10, 6))
sns.barplot(x='P_neighborhood', y='Frequency', hue='TS_on_socialmedia', data=freq_data)
plt.title('Distribution of time spent on social media by region')
plt.xlabel('Area')
plt.ylabel('Frequency')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# Calculate the number of children at home by age group and neighborhood
grouped_data = data.groupby('P_neighborhood')[['No_of_kids_at_home_0_11', 'No_of_kids_at_home_above_12']].sum()

# Create graph for children at home
grouped_data.plot(kind='bar', stacked=True, figsize=(10, 7))

# Add title and labels
plt.title('Number of Children at home by Age Group and Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Children at home')
plt.xticks(rotation=0)

# Add the legend
plt.legend(title='Age groups at home', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot with tight layout
plt.tight_layout()
plt.show()

# %%
g6=sns.catplot(kind='swarm',data=data,y='Child_owns_smartphone_age',x='P_income',order=['9-11','5-8','3-4','0-2'],hue='Child_first_age_smartphone',aspect=1.2) #,errorbar=None for lineplot
g6.set(xlabel='Parent Income',ylabel='Age of a child who Own a smartphone',title='Age distrbituion of child using a smartphone for first time VS Having a own smartphone')
g6._legend.set(title='Age when the child started using smartphone',loc='lower right',bbox_to_anchor=(1.1,0.06))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Calculate the frequency of each type of social media usage time per region
freq_data = data.groupby(['P_neighborhood', 'TS_on_socialmedia']).size().reset_index(name='Frequency')

# Calculate the number of children at home by age group and neighborhood
children_data = data.groupby('P_neighborhood')[['No_of_kids_at_home_0_11', 'No_of_kids_at_home_above_12']].sum().reset_index()

# Merge the two datasets on 'P_neighborhood'
merged_data = pd.merge(freq_data, children_data, on='P_neighborhood')

# Create a figure and a set of subplots
fig, ax1 = plt.subplots(figsize=(12, 6))

# Barplot for social media usage frequency
sns.barplot(x='P_neighborhood', y='Frequency', hue='TS_on_socialmedia', data=freq_data, ax=ax1)
ax1.set_title('Social Media Usage & Number of Children at Home by Neighborhood')
ax1.set_xlabel('Neighborhood')
ax1.set_ylabel('Frequency of Social Media Usage')
ax1.legend(loc='upper left', title='Time Spent on Social Media')

# Create a second y-axis to display the number of children at home
ax2 = ax1.twinx()
sns.barplot(x='P_neighborhood', y='No_of_kids_at_home_0_11', color='lightblue', data=children_data, ax=ax2, alpha=0.5)
sns.barplot(x='P_neighborhood', y='No_of_kids_at_home_above_12', color='darkblue', data=children_data, ax=ax2, alpha=0.5)
ax2.set_ylabel('Number of Children at Home')
ax2.legend(['0-11 years old', 'Above 12'], loc='upper right', title='Age Groups at Home')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Assume 'TS_on_socialmedia' is a categorical variable representing the time spent on social media
# and 'P_neighborhood' represents different neighborhoods.

# Since 'No_of_kids_at_home_0_11' and 'No_of_kids_at_home_above_12' are numeric, we can represent them as sizes.
# First, we normalize these columns to a suitable scale for the size parameter in scatterplot.
data['Size_0_11'] = (data['No_of_kids_at_home_0_11'] / data['No_of_kids_at_home_0_11'].max()) * 100
data['Size_above_12'] = (data['No_of_kids_at_home_above_12'] / data['No_of_kids_at_home_above_12'].max()) * 100

# Create scatter plot
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(data=data, x='P_neighborhood', y='TS_on_socialmedia',
                          size='Size_0_11', sizes=(20, 200), hue='Size_above_12', palette='coolwarm', legend=False)

# Because the sizes represent 'No_of_kids_at_home_0_11', we add a size legend manually
for size in [20, 100, 200]:
    plt.scatter([], [], c='k', alpha=0.3, s=size,
                label=str(size) + ' Kids at home 0-11')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='Kids at home')

# Set plot title and labels
plt.title('Social Media Usage and Number of Kids at Home by Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Time Spent on Social Media')

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Add some jitter (random noise) to the 'No_of_kids_at_home_0_11' values to spread the points out for visibility
data['No_of_kids_at_home_0_11_jittered'] = data['No_of_kids_at_home_0_11'] + np.random.normal(0, 0.1, size=len(data))

# Add some jitter to the 'No_of_kids_at_home_above_12' values as well
data['No_of_kids_at_home_above_12_jittered'] = data['No_of_kids_at_home_above_12'] + np.random.normal(0, 0.1, size=len(data))

# Define marker styles for different 'TS_on_socialmedia' categories
markers = {
    'Too much time': 'X', 
    'About the right amount of time': 'o', 
    'Too little time': 's', 
    'Refused': 'd'
}

# Create a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=data,
    x='P_neighborhood',  # Neighborhoods will be on the x-axis
    y='No_of_kids_at_home_0_11_jittered',  # Use jittered values for y-axis
    style='TS_on_socialmedia',  # Use different markers for social media time categories
    hue='No_of_kids_at_home_above_12',  # Use a color gradient for the number of older kids
    markers=markers,  # Set marker styles
    palette='coolwarm',  # Color palette for older kids
    s=100,  # Uniform size for all markers
    alpha=0.6  # Semi-transparency for markers
)

# Add a legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0., title='Time Spent on Social Media')

# Add titles and labels
plt.title('Social Media Usage and Number of Kids at Home by Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Kids at Home Aged 0-11')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Remove entries where 'P_neighborhood' is 'Refused'
data = data[data['P_neighborhood'] != 'Refused']

# Add jitter to the 'P_neighborhood' categorical data for better visualization
# We use a categorical variable to numeric mapping to apply jitter
neighborhood_order = ['Rural', 'Suburban', 'Urban']  # Define the order of categories
data['P_neighborhood'] = pd.Categorical(data['P_neighborhood'], categories=neighborhood_order, ordered=True)
data['P_neighborhood_jittered'] = data['P_neighborhood'].cat.codes + np.random.uniform(-0.2, 0.2, size=len(data))

# Define the size mapping for the 'TS_on_socialmedia' categories
size_mapping = {
    'Too much time': 200,
    'About the right amount of time': 100,
    'Too little time': 50,
}
data['TS_on_socialmedia_size'] = data['TS_on_socialmedia'].map(size_mapping)

# Create a scatter plot
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(
    data=data,
    x='P_neighborhood_jittered',  # Jittered neighborhood on x-axis
    y='No_of_kids_at_home_0_11',  # Kids aged 0-11 on y-axis
    size='No_of_kids_at_home_above_12',  # Kids aged above 12 represented by size
    sizes=(20, 200),  # Control the range of sizes
    hue='TS_on_socialmedia_size',  # Time spent on social media represented by color
    palette='coolwarm',  # Color palette for social media time
    legend='full',
    alpha=0.6  # Semi-transparency for markers
)

# Add a legend with title
plt.legend(title='Number of Kids at Home Above 12 & Social Media Usage', bbox_to_anchor=(1.05, 1), loc='upper left')

# Add titles and labels
plt.title('Social Media Usage and Number of Kids at Home by Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Kids at Home Aged 0-11')

# Set custom x-ticks to match the neighborhood categories
plt.xticks(ticks=np.arange(len(neighborhood_order)), labels=neighborhood_order)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Remove entries where 'P_neighborhood' is 'Refused'
data = data[data['P_neighborhood'] != 'Refused']

# Convert 'P_neighborhood' into a categorical type and order it
neighborhood_order = ['Rural', 'Suburban', 'Urban']  # Define the order of categories
data['P_neighborhood'] = pd.Categorical(data['P_neighborhood'], categories=neighborhood_order, ordered=True)

# Convert 'TS_on_socialmedia' into ordered categories and then into numeric codes
time_order = ['Too little time', 'About the right amount of time', 'Too much time']  # Define the order of time spent categories
data['TS_on_socialmedia'] = pd.Categorical(data['TS_on_socialmedia'], categories=time_order, ordered=True)
data['TS_on_socialmedia_size'] = data['TS_on_socialmedia'].cat.codes

# Define the size of the points based on the 'No_of_kids_at_home_0_11'
# You may need to adjust the scaling factor for the size to suit your data
data['size'] = data['No_of_kids_at_home_0_11'].apply(lambda x: x*10)

# Create a scatter plot
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(
    data=data,
    x='P_neighborhood',  # Neighborhood on x-axis
    y='TS_on_socialmedia_size',  # Time spent on social media on y-axis
    size='size',  # Kids aged 0-11 represented by size
    sizes=(20, 200),  # Control the range of sizes
    hue='No_of_kids_at_home_above_12',  # Kids aged above 12 represented by color
    palette='coolwarm',  # Color palette for kids aged above 12
    legend='full',
    alpha=0.6  # Semi-transparency for markers
)

# Add a legend with title
plt.legend(title='Number of Kids at Home Aged 0-11', bbox_to_anchor=(1.05, 1), loc='upper left')

# Add titles and labels
plt.title('Social Media Usage and Number of Kids at Home by Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Time Spent on Social Media Size')

# Set the y-ticks to match the time spent categories
plt.yticks(ticks=np.arange(len(time_order)), labels=time_order)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Remove entries where 'TS_on_socialmedia' is 'Refused' or 'P_neighborhood' is 'Refused'
data = data[(data['TS_on_socialmedia'] != 'Refused') & (data['P_neighborhood'] != 'Refused')]

# Convert 'P_neighborhood' and 'TS_on_socialmedia' into ordered categorical types for plotting
data['P_neighborhood'] = pd.Categorical(data['P_neighborhood'], categories=['Rural', 'Suburban', 'Urban'], ordered=True)
data['TS_on_socialmedia'] = pd.Categorical(data['TS_on_socialmedia'], categories=['Too little time', 'About the right amount of time', 'Too much time'], ordered=True)

# Create a scatter plot
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(data=data, x='P_neighborhood', y='TS_on_socialmedia', 
                          hue='No_of_kids_at_home_0_11', palette='Blues', legend='full', s=100)

# Add a legend with title
plt.legend(title='Number of Kids at Home Aged 0-11', bbox_to_anchor=(1.05, 1), loc='upper left')

# Add titles and labels
plt.title('Social Media Usage and Number of Kids at Home by Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Time Spent on Social Media')

# Adjust the y-axis to show the ordered categories for 'TS_on_socialmedia'
plt.yticks(range(len(data['TS_on_socialmedia'].cat.categories)), data['TS_on_socialmedia'].cat.categories)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Remove entries where 'TS_on_socialmedia' is 'Refused' or 'P_neighborhood' is 'Refused'
data = data[(data['TS_on_socialmedia'] != 'Refused') & (data['P_neighborhood'] != 'Refused')]

# Convert 'P_neighborhood' and 'TS_on_socialmedia' into ordered categorical types for plotting
data['P_neighborhood'] = pd.Categorical(data['P_neighborhood'], categories=['Rural', 'Suburban', 'Urban'], ordered=True)
data['TS_on_socialmedia'] = pd.Categorical(data['TS_on_socialmedia'], categories=['Too little time', 'About the right amount of time', 'Too much time'], ordered=True)

# Create a scatter plot
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(data=data, x='P_neighborhood', y='TS_on_socialmedia', 
                          hue='No_of_kids_at_home_0_11', palette='Blues', legend='full', s=100)

# Add a legend with title
plt.legend(title='Number of Kids at Home Aged 0-11', bbox_to_anchor=(1.05, 1), loc='upper left')

# Add titles and labels
plt.title('Social Media Usage and Number of Kids at Home by Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Time Spent on Social Media')

# Adjust the y-axis to show the ordered categories for 'TS_on_socialmedia'
plt.yticks(range(len(data['TS_on_socialmedia'].cat.categories)), data['TS_on_socialmedia'].cat.categories)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Placeholder data for demonstration
data = pd.DataFrame({
    'advice_socialmedia': ['Yes', 'No', 'Yes', 'Yes', 'No'],
    'advice_online_blogs': ['No', 'Yes', 'Yes', 'No', 'No'],
    'advice_other_parents': ['Yes', 'Yes', 'No', 'Yes', 'Yes'],
    'advice_books_magazines': ['No', 'No', 'Yes', 'No', 'Yes'],
    'advice_doctors': ['Yes', 'Yes', 'No', 'Yes', 'No'],
    'advice_teachers': ['No', 'No', 'Yes', 'No', 'Yes']
})

# Convert 'Yes'/'No' answers to binary values 1/0
binary_mapping = {'Yes': 1, 'No': 0}
for column in data.columns:
    data[column] = data[column].map(binary_mapping)

# Calculate the proportion of 'Yes' responses for each advice source
proportion_yes = data.mean()

# Calculate the proportion of 'No' responses
proportion_no = 1 - proportion_yes

# Combine the two into a DataFrame
heatmap_data = pd.concat([proportion_yes, proportion_no], axis=1)
heatmap_data.columns = ['Yes', 'No']

# Define a custom black-purple-black color map
cmap = sns.color_palette(["black", "#4A148C", "black", "#4A148C"], as_cmap=True)

# Create the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap=cmap, fmt=".2f")

# Add titles and labels
plt.title('Proportion of Respondents Saying Yes/No to Getting Screen Time Advice from Various Sources')
plt.xlabel('Response')
plt.ylabel('Sources of Advice')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming the data is loaded from 'pre_processed_data.csv'
# data = pd.read_csv('pre_processed_data.csv')

# For demonstration, using a placeholder DataFrame
# Replace this with the actual data loading code
data = pd.DataFrame({
    'TS_on_smartphone': ['Too much time', 'About the right amount of time', 'Too little time', 'Too much time', 'About the right amount of time'],
    'TS_on_socialmedia': ['About the right amount of time', 'Too little time', 'Too much time', 'Too little time', 'About the right amount of time'],
    'TS_on_videogames': ['Too little time', 'Too much time', 'About the right amount of time', 'Too little time', 'Too much time']
})

# Convert response categories to numeric
time_mapping = {'Too much time': 2, 'About the right amount of time': 1, 'Too little time': 0}
for column in data.columns:
    data[column] = data[column].map(time_mapping)

# Convert the numeric responses back to categories for each column
data_melted = pd.melt(data, var_name='Activity', value_name='Response')
response_counts = data_melted.groupby(['Activity', 'Response']).size().reset_index(name='Count')

# Pivot the data for the heatmap
pivot_table = response_counts.pivot(index='Activity', columns='Response', values='Count')

# Create the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, cmap="YlGnBu", fmt="d")

# Add titles and labels
plt.title('Count of Responses for Time Spent on Various Activities')
plt.xlabel('Response')
plt.ylabel('Activity')

# Adjust the x-axis to show the response categories
plt.xticks(ticks=[0.5, 1.5, 2.5], labels=['Too little time', 'About the right amount of time', 'Too much time'])

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Placeholder data for demonstration
data = pd.DataFrame({
    'CO_online_bully': ['Somewhat concerned', 'Very concerned', 'Not at all concerned', 'Not too concerned', 'Somewhat concerned'],
    'CO_screen_time': ['Not too concerned', 'Somewhat concerned', 'Very concerned', 'Not at all concerned', 'Somewhat concerned'],
    'CO_sexual_explicit_content': ['Very concerned', 'Somewhat concerned', 'Not at all concerned', 'Not too concerned', 'Very concerned'],
    'CO_online_fraud': ['Not at all concerned', 'Very concerned', 'Somewhat concerned', 'Not too concerned', 'Somewhat concerned'],
    'CO_violent_content': ['Somewhat concerned', 'Not too concerned', 'Very concerned', 'Not at all concerned', 'Somewhat concerned']
})

# Convert response categories to numeric
concern_mapping = {
    'Very concerned': 3, 
    'Somewhat concerned': 2, 
    'Not too concerned': 1, 
    'Not at all concerned': 0
}

# Apply mapping and transpose the dataframe for the heatmap
heatmap_data = data.replace(concern_mapping).transpose()

# Compute the proportion of each response category for the heatmap
heatmap_data = heatmap_data.apply(lambda x: x.value_counts(normalize=True), axis=1).fillna(0)

# Define a custom color map
cmap = sns.diverging_palette(240, 10, n=9, as_cmap=True)

# Create the heatmap
plt.figure(figsize=(12, 7))
sns.heatmap(heatmap_data, annot=True, cmap=cmap, fmt=".2f")

# Add titles and labels
plt.title('Proportion of Concern Levels for Various Online Concerns')
plt.xlabel('Concern Levels')
plt.ylabel('Online Concerns')

# Adjust the x-axis to show the response categories in the desired order
response_categories = ['Not at all concerned', 'Not too concerned', 'Somewhat concerned', 'Very concerned']
plt.xticks(ticks=np.arange(len(response_categories)) + 0.5, labels=response_categories, rotation=0)

# Adjust the y-axis to remove 'CO_' prefix and display the concerns
concern_labels = [label.replace('CO_', '') for label in heatmap_data.index]
plt.yticks(ticks=np.arange(len(concern_labels)) + 0.5, labels=concern_labels, rotation=0)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np


# Placeholder data for demonstration
data = pd.DataFrame({
    'CO_online_bully': ['Somewhat concerned', 'Very concerned', 'Not at all concerned', 'Not too concerned', 'Somewhat concerned'],
    'CO_screen_time': ['Not too concerned', 'Somewhat concerned', 'Very concerned', 'Not at all concerned', 'Somewhat concerned'],
    'CO_sexual_explicit_content': ['Very concerned', 'Somewhat concerned', 'Not at all concerned', 'Not too concerned', 'Very concerned'],
    'CO_online_fraud': ['Not at all concerned', 'Very concerned', 'Somewhat concerned', 'Not too concerned', 'Somewhat concerned'],
    'CO_violent_content': ['Somewhat concerned', 'Not too concerned', 'Very concerned', 'Not at all concerned', 'Somewhat concerned']
})

# Convert response categories to numeric
concern_mapping = {
    'Very concerned': 3, 
    'Somewhat concerned': 2, 
    'Not too concerned': 1, 
    'Not at all concerned': 0
}

# Apply mapping and transpose the dataframe for the heatmap
heatmap_data = data.replace(concern_mapping).transpose()

# Compute the proportion of each response category for the heatmap
heatmap_data = heatmap_data.apply(lambda x: x.value_counts(normalize=True), axis=1).fillna(0)

# Define a custom color map for a black to purple gradient
cmap = sns.color_palette("Purples", as_cmap=True)

# Create the heatmap
plt.figure(figsize=(12, 7))
sns.heatmap(heatmap_data, annot=True, cmap=cmap, fmt=".2f")

# Add titles and labels
plt.title('Proportion of Concern Levels for Various Online Concerns')
plt.xlabel('Concern Levels')
plt.ylabel('Online Concerns')

# Adjust the x-axis to show the response categories in the desired order
response_categories = ['Not at all concerned', 'Not too concerned', 'Somewhat concerned', 'Very concerned']
plt.xticks(ticks=np.arange(len(response_categories)) + 0.5, labels=response_categories, rotation=0)

# Adjust the y-axis to remove 'CO_' prefix and display the concerns
concern_labels = [label.replace('CO_', '') for label in heatmap_data.index]
plt.yticks(ticks=np.arange(len(concern_labels)) + 0.5, labels=concern_labels, rotation=0)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from  matplotlib.ticker import PercentFormatter
from sklearn.preprocessing import LabelEncoder

# %%
def add_percentage_labels_for_advice(plot, feature, ax,max_count):
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width() / max_count)
        x = p.get_x() + p.get_width()
        y = p.get_y()
        #print(p)
        #print(f'percentage of {percentage}, (x,y) is {(x,y)}')
        ax.annotate(percentage, (x+50, y+0.2), fontsize=10, color='black')

# %%
data=pd.read_csv('pre_processed_data.csv')

# %%
dfm=data[['ADV_socialmedia','ADV_online_blogs','ADV_other_parents','ADV_books_magazines','ADV_doctors','ADV_teachers']].melt(var_name='advice_from', value_name='response')

# %%
sns.catplot(kind='swarm',data=data,x='Child_owns_smartphone_age',y='P_employment_type',order=['0-2','3-4','5-8','9-11'],hue='Child_first_age_smartphone') #,errorbar=None for lineplot
# Out:
# /Users/mac/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3370: UserWarning: 70.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/mac/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3370: UserWarning: 80.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/mac/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/mac/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3370: UserWarning: 15.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.ticker import PercentFormatter
from sklearn.preprocessing import LabelEncoder


data = pd.read_csv('pre_processed_data.csv')

if 'P_employment_type' in data.columns:
    data.rename(columns={'P_employment_type': 'employment_type'}, inplace=True)

dfm = data[['ADV_socialmedia', 'ADV_online_blogs', 'ADV_other_parents', 'ADV_books_magazines', 'ADV_doctors', 'ADV_teachers']].melt(var_name='advice_from', value_name='response')

sns.catplot(kind='swarm', data=data, x='Child_owns_smartphone_age', y='employment_type', order=['0-2', '3-4', '5-8', '9-11'], hue='Child_first_age_smartphone')
plt.show()
# Out:
# /Users/mac/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3370: UserWarning: 70.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/mac/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3370: UserWarning: 80.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/mac/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/mac/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3370: UserWarning: 15.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.catplot(kind='swarm',data=data,x='Child_owns_smartphone_age',y='P_race',order=['0-2','3-4','5-8','9-11'],hue='Child_first_age_smartphone',aspect=1.6) #,errorbar=None for lineplot
# Out:
# /Users/mac/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3370: UserWarning: 40.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/mac/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3370: UserWarning: 62.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/mac/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/mac/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3370: UserWarning: 56.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.ticker import PercentFormatter
from sklearn.preprocessing import LabelEncoder

# Load data
data = pd.read_csv('pre_processed_data.csv')

# Rename 'P_race' to 'Race' in the DataFrame
data.rename(columns={'P_race': 'Race'}, inplace=True)
data.rename(columns={'Child_owns_smartphone_age': 'Child owns smartphone age'}, inplace=True)

# Continue with the visualization or other analysis
dfm = data[['ADV_socialmedia', 'ADV_online_blogs', 'ADV_other_parents', 'ADV_books_magazines', 'ADV_doctors', 'ADV_teachers']].melt(var_name='advice_from', value_name='response')

# Create a categorical plot with the new 'Race' column as the y-axis
sns.catplot(kind='swarm', data=data, x='Child_owns_smartphone_age', y='Race', order=['0-2', '3-4', '5-8', '9-11'], hue='Child_first_age_smartphone', aspect=1.6)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 19
#      16 dfm = data[['ADV_socialmedia', 'ADV_online_blogs', 'ADV_other_parents', 'ADV_books_magazines', 'ADV_doctors', 'ADV_teachers']].melt(var_name='advice_from', value_name='response')
#      18 # Create a categorical plot with the new 'Race' column as the y-axis
# ---> 19 sns.catplot(kind='swarm', data=data, x='Child_owns_smartphone_age', y='Race', order=['0-2', '3-4', '5-8', '9-11'], hue='Child_first_age_smartphone', aspect=1.6)
#      21 plt.show()
#
# ...
